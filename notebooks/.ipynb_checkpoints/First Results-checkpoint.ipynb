# %%
pwd
# Out:
# u'/Users/Nakis/PycharmProjects/Kaggle/NCAA/MMML2014/notebooks'

# %%
cd ..
# Out:
# /Users/Nakis/PycharmProjects/Kaggle/NCAA/MMML2014

# %%
from scripts.Logistic import Logistic

# %%
L = Logistic('raw_data/regular_season_results.csv', 'raw_data/tourney_results.csv')
L.train()
pred, idx = L.predict('raw_data/tourney_seeds.csv', 'S')

# %%
import pandas as pd
a = pd.DataFrame(pred, index = idx)

# %%
a
# Out:
#                    0         1
# (507, 509)  0.700746  0.299254
# (507, 511)  0.972519  0.027481
# (507, 512)  0.882885  0.117115
# (507, 521)  0.912266  0.087734
# (507, 536)  0.903440  0.096560
# (507, 538)  0.582641  0.417359
# (507, 549)  0.920364  0.079636
# (507, 553)  0.524058  0.475942
# (507, 556)  0.872431  0.127569
# (507, 559)  0.922744  0.077256
# (507, 562)  0.949071  0.050929
# (507, 569)  0.878444  0.121556
# (507, 570)  0.736947  0.263053
# (507, 577)  0.957502  0.042498
# (507, 580)  0.704398  0.295602
# (507, 592)  0.960425  0.039575
# (507, 599)  0.881809  0.118191
# (507, 607)  0.917674  0.082326
# (507, 612)  0.836766  0.163234
# (507, 628)  0.927683  0.072317
# (507, 629)  0.936086  0.063914
# (507, 636)  0.964873  0.035127
# (507, 637)  0.870738  0.129262
# (507, 640)  0.947130  0.052870
# (507, 651)  0.972350  0.027650
# (507, 658)  0.792783  0.207217
# (507, 663)  0.890127  0.109873
# (507, 666)  0.893005  0.106995
# (507, 667)  0.795800  0.204200
# ...
